# %%
import pandas as pd

# %%
import os

# %% [markdown]
# # PPO Analysis

# %%
from stable_baselines3.common.results_plotter import X_TIMESTEPS, plot_results
import matplotlib.pyplot as plt

# %%
base = './logs/tmp_mp_ppo/'

timesteps = 1e6 * 5
plot_results(
    [base], timesteps, X_TIMESTEPS, "PPO FruitBot", figsize=(10, 5)
)
plt.yticks([i for i in range(-20, 20, 4)])
plt.show()

# %%
base = './logs/tmp_ppo_reward=new/'

timesteps = 1e6 * 5
plot_results(
    [base], timesteps, X_TIMESTEPS, "PPO FruitBot", figsize=(10, 5)
)
plt.yticks([i for i in range(-20, 20, 4)])
plt.show()

# %% [markdown]
# # DQN Analysis

# %%
base = './tmp_mp_dqn/'

timesteps = 1e6 * 5
plot_results(
    [base], timesteps, X_TIMESTEPS, "DQN FruitBot", figsize=(10, 5)
)
plt.yticks([i for i in range(-20, 20, 4)])
plt.show()

# %% [markdown]
# # A2C Analysis

# %%
base = './tmp_mp_a2c/'

timesteps = 1e6 * 5
plot_results(
    [base], timesteps, X_TIMESTEPS, "DQN FruitBot", figsize=(10, 5)
)
plt.yticks([i for i in range(-20, 20, 4)])
plt.show()
